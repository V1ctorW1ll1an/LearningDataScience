# %%
from scratch.linear_algebra import dot

# %% [markdown]
# https://github.com/joelgrus/data-science-from-scratch/blob/master/scratch/statistics.py

# %%
from data.num_friends import num_friends

# %%
from collections import Counter
import matplotlib.pyplot as plt

friend_counts = Counter(num_friends)
xs = range(101)   # o maior valor é 100
ys = [friend_counts[x] for x in xs]
plt.bar(xs, ys)
plt.axis([0, 101, 0, 25])
plt.title('Histograma das contagens de amigos')
plt.xlabel('n˚ de amigos')
plt.ylabel('n˚ de pessoas')
plt.show()

# %%
num_points = len(num_friends)

# %%
largest_value = max(num_friends)

smallest_value = min(num_friends)

# %%
sorted_values = sorted(num_friends)
seconds_smallest_value = sorted_values[1]
second_largest_value = sorted_values[-2]

# %%
from scratch.statistic import mean

print(mean(num_friends))
# Out:
# 7.333333333333333

# %%
from scratch.linear_algebra import sum_of_squares


def de_mean(xs: List[float]) -> List[float]:
    """Traduza xs subtraindo sua media (para que o resultado tenha media 0)"""
    x_bar = mean(xs)
    return [x - x_bar for x in xs]
